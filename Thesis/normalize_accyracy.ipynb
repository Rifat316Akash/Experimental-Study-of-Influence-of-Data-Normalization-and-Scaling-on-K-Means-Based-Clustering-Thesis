# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math 
from sklearn import preprocessing

# %%
ds=pd.read_csv('F:/Course Study/Thesis(Musharrat Mam)/iris_data.csv')

# %%
ds_1=ds.iloc[:,0:4]

# %%
ds_1
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
mn=preprocessing.MinMaxScaler()

# %%
normalize = mn.fit_transform(ds)

# %%
normalize
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667, 0.        ],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667, 0.        ],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667, 0.        ],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667, 0.        ],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667, 0.        ],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     , 0.        ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333, 0.        ],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667, 0.        ],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667, 0.        ],
#        [0.16666667, 0.45833333, 0.08474576, 0.        , 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667, 0.        ],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667, 0.        ],
#        [0.13888889, 0.41666667, 0.06779661, 0.        , 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        , 0.        ],
# ...

# %%
print(normalize[0])
# Out:
# [0.22222222 0.625      0.06779661 0.04166667 0.        ]

# %%
import random
random.seed(5)

one  = random.randint(0, 149)
two = random.randint(0, 149)
three = random.randint(0, 149)

print(one)
print(two)
print(three)
# Out:
# 65
# 91
# 135

# %%
c1 = []
c2 = []
c3 = []

c1 = normalize[one]
print(c1)

c2 = normalize[two]
print(c2)

c3 = normalize[three]
print(c3)
# Out:
# [0.66666667 0.45833333 0.57627119 0.54166667 0.5       ]
# [0.5        0.41666667 0.61016949 0.54166667 0.5       ]
# [0.94444444 0.41666667 0.86440678 0.91666667 1.        ]

# %%
def dis(source, dst):
    sum = 0
    for i in range(4):
        x = source[i] - dst[i];
        x = x*x    
        sum += x
    return math.sqrt(sum)

# %%
def update(c):
    up = []
    
    for i in range(4):
        sum = 0
        for j in range(len(c)):
            sum += c[j][i]
        up.append(sum/len(c))
    return up

# %%
cl1 = []
cl2 = []
cl3 = []
for i in range(15):
    cl1 = []
    cl2 = []
    cl3 = []
    for j in range(150):
        d1 = dis(c1, normalize[j])
        d2 = dis(c2, normalize[j])
        d3 = dis(c3, normalize[j])
        m = min(d1,d2,d3)
        
        if (m==d1):
            cl1.append(normalize[j])
        elif (m==d2):
            cl2.append(normalize[j])
        else:
            cl3.append(normalize[j])    
    
    c1 = update(cl1)
    c2 = update(cl2)
    c3 = update(cl3)
    
print(c1)
print(c2)
print(c3)
# Out:
# [0.4412568306010931, 0.3073770491803279, 0.5757154765212558, 0.5491803278688525]
# [0.1961111111111111, 0.5908333333333332, 0.07864406779661014, 0.05999999999999999]
# [0.7072649572649572, 0.45085470085470103, 0.7970447631464581, 0.8247863247863247]

# %%
cn1 = 0
cn2 = 0
cn3 = 0
for i in range(len(cl1)):
    if(cl1[i][4]==0):
        cn1+=1
    elif(cl1[i][4]==0.5):
        cn2+=1  
    else:
        cn3+=1    
        
print(cn1)
print(cn2)
print(cn3)
m1 = max(cn1,cn2,cn3)
# Out:
# 0
# 47
# 14

# %%
cn11 = 0
cn22 = 0
cn33 = 0

for i in range(len(cl2)):
    if(cl2[i][4]==0):
        cn11+=1
    elif(cl2[i][4]==0.5):
        cn22+=1  
    else:
        cn33+=1     
print(cn11)
print(cn22)
print(cn33)
m2 = max(cn11,cn22,cn33)
# Out:
# 50
# 0
# 0

# %%
cn111 = 0
cn222 = 0
cn333= 0
for i in range(len(cl3)):
    if(cl3[i][4]==0):
        cn111+=1
    elif(cl3[i][4]==0.5):
        cn222+=1  
    else:
        cn333+=1 
print(cn111)
print(cn222)
print(cn333)
m3 = max(cn111,cn222,cn333)
# Out:
# 0
# 3
# 36

# %%
print("Setosa: " + str(cn1) +" "+str(cn11) +" "+str(cn111))
print("Versicolor: " + str(cn2)+" "+ str(cn22)+" "+ str(cn222))
print("Virginica: " + str(cn3)+" "+ str(cn33)+" "+ str(cn333))
# Out:
# Setosa: 0 50 0
# Versicolor: 47 0 3
# Virginica: 14 0 36

# %%
m = (m1+m2+m3)/150
print(m*100)
# Out:
# 88.66666666666667
